# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Twitter Dataset

# %%
twitter = pd.read_excel("twitter.xlsx")
twitter.head()
# Out:
#    title                                            content  \
# 0    NaN  Kalvin Phillips hopeful of World Cup inclusion...
# 1    NaN  Qatar promises a 'carbon-neutral' FIFA World C...
# 2    NaN  Qatar's promise of 'carbon-neutral' World Cup ...
# 3    NaN  Around 6,000 Argentine Fans Banned from Stadiu...
# 4    NaN  Happy World Cup Final Day!. Argentina to win 2...
#
#                      from      locatiion                date images  \
# 0              myKhel.com      Bengaluru 2022-11-08 10:40:56     []
# 1                Republic  Mumbai, India 2022-11-08 10:58:55     []
# 2  Carbon Credit Research      Worldwide 2022-11-08 11:08:09     []
# 3            Viral Cyprus      Worldwide 2022-11-08 12:00:50     []
# 4                 MrX_NFT            NaN 2022-12-18 16:21:57     []
#
#                                                  url                      by  \
# 0  https://twitter.com/mykhelcom/status/158981016...              myKhel.com
# 1  https://twitter.com/republic/status/1589814697...                Republic
# 2  https://twitter.com/CarbonCreditRes/status/158...  Carbon Credit Research
# 3  https://twitter.com/viralposthq/status/1589830...            Viral Cyprus
# 4  https://twitter.com/MrX__NFT/status/1604391505...                 MrX_NFT
#
#    likes  shares
# 0      0       0
# 1     10       1
# 2      0       0
# 3      0       0
# 4      0       0

# %%
twitter = twitter.drop_duplicates() #Eliminates duplicate values
twitter = twitter.drop(columns=["title", "images", "url", "by"])

new_column_names = {
    "content": "Title",
    "from": "Publisher",
    "locatiion": "Location",
    "date": "Date",
    "likes": "Likes",
    "shares": "Shares"
}
twitter = twitter.rename(columns=new_column_names)
twitter
# Out:
#                                                    Title  \
# 0      Kalvin Phillips hopeful of World Cup inclusion...
# 1      Qatar promises a 'carbon-neutral' FIFA World C...
# 2      Qatar's promise of 'carbon-neutral' World Cup ...
# 3      Around 6,000 Argentine Fans Banned from Stadiu...
# 4      Happy World Cup Final Day!. Argentina to win 2...
# ...                                                  ...
# 27503  FIFA World Cup 2022: Sometimes things don’t go...
# 27504  ⚽️ FIFA World Cup Qatar 2022 Match schedule:⚽️...
# 27505  Please am I only one that has not yet watched ...
# 27506  This is what the #FIFAWorldCup is all about;\n...
# 27507  Only if i knew that tuning into serbia vs came...
#
#                     Publisher       Location                Date  Likes  \
# 0                  myKhel.com      Bengaluru 2022-11-08 10:40:56      0
# 1                    Republic  Mumbai, India 2022-11-08 10:58:55     10
# 2      Carbon Credit Research      Worldwide 2022-11-08 11:08:09      0
# 3                Viral Cyprus      Worldwide 2022-11-08 12:00:50      0
# 4                     MrX_NFT            NaN 2022-12-18 16:21:57      0
# ...                       ...            ...                 ...    ...
# 27503      Daily News hunt 24         Mumbai 2022-11-28 21:24:41      0
# 27504             K8 Official            NaN 2022-11-29 03:13:17      5
# 27505              Anas zurmi       Nigeria. 2022-11-29 03:13:26      5
# 27506    FIFA World Cup Stats       Global � 2022-11-28 21:47:41    124
# 27507               TradeStar  Mumbai, India 2022-11-28 21:47:47      0
#
#        Shares
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ...       ...
# 27503       0
# 27504       1
# 27505       0
# 27506      28
# 27507       0
#
# [27508 rows x 6 columns]

# %%
twitter.dtypes
# Out:
# Title                object
# Publisher            object
# Location             object
# Date         datetime64[ns]
# Likes                 int64
# Shares                int64
# dtype: object

# %%
twitter.shape
# Out:
# (27508, 6)

# %%
twitter.describe()
# Out:
#                Likes         Shares
# count   27508.000000   27508.000000
# mean      186.251854      45.223971
# std      4939.797974    1552.419537
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         3.000000       1.000000
# max    629808.000000  236759.000000

# %%
likes_percentiles = twitter["Likes"].describe(percentiles=[.50, .60, .70, .75, .80, .85, .90, .95, .96, .97, .98, .99, .995, .999])

print(likes_percentiles)
# Out:
# count     27508.000000
# mean        186.251854
# std        4939.797974
# min           0.000000
# 50%           0.000000
# 60%           1.000000
# 70%           2.000000
# 75%           3.000000
# 80%           5.000000
# 85%          10.000000
# 90%          23.000000
# 95%          75.000000
# 96%         109.720000
# 97%         174.790000
# 98%         347.000000
# 99%        1307.670000
# 99.5%      4133.905000
# 99.9%     43192.497000
# max      629808.000000
# Name: Likes, dtype: float64

# %%
shares_percentiles = twitter["Shares"].describe(percentiles=[.50, .75,  .85, .90, .95, .96, .97, .98, .99, .995, .999])

print(shares_percentiles)
# Out:
# count     27508.000000
# mean         45.223971
# std        1552.419537
# min           0.000000
# 50%           0.000000
# 75%           1.000000
# 85%           3.000000
# 90%           7.000000
# 95%          23.000000
# 96%          34.000000
# 97%          52.000000
# 98%         102.000000
# 99%         482.930000
# 99.5%      1381.000000
# 99.9%      7717.000000
# max      236759.000000
# Name: Shares, dtype: float64

# %%
publisher_counts = twitter['Publisher'].value_counts()

publisher_counts.head(10)
# Out:
# Gulf-Times              342
# The Voice of America    121
# beIN SPORTS             107
# Robbie Sparkes           98
# #YFM                     89
# Metro                    83
# AFP news agency          78
# Sky News                 73
# Andy Vermaut             56
# AP Sports                53
# Name: Publisher, dtype: int64

# %%
location_counts = twitter['Location'].value_counts()

location_counts.head(20)
# Out:
# London                    433
# London, England           355
# United States             348
# Al Hilal - C Ring Road    342
# Nigeria                   319
# United Kingdom            311
# London, UK                261
# Doha, Qatar               232
# India                     221
# Lagos, Nigeria            213
# South Africa              202
# Australia                 193
# New York, NY              185
# Qatar                     156
# Global                    142
# Singapore                 136
# Pakistan                  130
# USA                       127
# Nairobi, Kenya            126
# Washington, DC            124
# Name: Location, dtype: int64

# %%
date_counts = twitter['Date'].dt.date.value_counts()

print(date_counts)
# Out:
# 2022-11-21    2802
# 2022-11-20    1909
# 2022-11-19    1329
# 2022-11-18    1089
# 2022-11-22     998
#               ...
# 2023-01-04       4
# 2023-01-08       3
# 2023-01-09       3
# 2023-01-07       2
# 2023-01-06       1
# Name: Date, Length: 92, dtype: int64

# %%
twitter.isna().sum()
# Out:
# Title           0
# Publisher       2
# Location     8365
# Date            0
# Likes           0
# Shares          0
# dtype: int64

# %%
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/farrelw/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/farrelw/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
twitter['Title'] = twitter['Title'].apply(lambda text: ' '.join([word for word in word_tokenize(text) if word.lower() not in stop_words]))

# %%
twitter['Title'] = twitter['Title'].apply(word_tokenize)

# %%
twitter.head()
# Out:
#                                                Title               Publisher  \
# 0  [Kalvin, Phillips, hopeful, World, Cup, inclus...              myKhel.com
# 1  [Qatar, promises, 'carbon-neutral, ', FIFA, Wo...                Republic
# 2  [Qatar, 's, promise, 'carbon-neutral, ', World...  Carbon Credit Research
# 3  [Around, 6,000, Argentine, Fans, Banned, Stadi...            Viral Cyprus
# 4  [Happy, World, Cup, Final, Day, !, ., Argentin...                 MrX_NFT
# 6593                   Qatar 2022-11-20 22:01:22   54461    8916

# %%
twitter_sort = twitter.sort_values(by=['Shares'], ascending=False)

twitter_sort.head(20)
# Out:
#                                                    Title            Publisher  \
# 11760  [방탄소년단, ‘, 정국, ’, 이, 2022, FIFA, 카타르, 월드컵, 공식,...         BTS_official
# 10585  [Jungkook, BTS, Qatari, singer, Fahad, Al, Kub...  The Peninsula Qatar
# 21390  [’, end, Cristiano, Ronaldo, World, Cup, ., Po...      Fabrizio Romano
# 11710  [�️, Abdullah, Al, Nasari, ,, Head, Security, ...    Football Tweet ⚽
# 10593  [Outrageously, disrespectful, Qatar, BBC, ’, b...         Piers Morgan
# 10412  [RT, @, piersmorgan, :, Outrageously, disrespe...           NEIL EVANS
# 10318  [RT, @, piersmorgan, :, Outrageously, disrespe...                 Chox
# 10934  [RT, @, ESPNFC, :, FIFA, President, Gianni, In...                 Chox
# 10933  [FIFA, President, Gianni, Infantino, Europe, '...              ESPN FC
# 10845  [RT, @, ESPNFC, :, FIFA, President, Gianni, In...              E Z R A
# 25127  [Lionel, Messi, :, “, ,, ’, gon, na, retire, n...      Fabrizio Romano
# 25996   [doubted, Qatar, Arabs, ,, World, cup, 2022, ♥️]          محمد الكعبي
# 8301   [Japanese, fans, opening, World, Cup, match, c...    Football Tweet ⚽
# 24209  [Nah, Qatar, delivered, best, World, Cup, ever...    tito’s rich uncle
# 21639  [RT, @, chawanz11, :, Nah, Qatar, delivered, b...              Sushant
# 25091  [’, sorry, World, Cup, submitted, Oscars, ,, E...              kanki ✨
# 21641  [RT, @, FabrizioRomano, :, Morocco, World, Cup...  Demetri Sevastopulo
# 22273  [Morocco, World, Cup, semi, finalist, !, face,...      Fabrizio Romano
# 23496  [NPR, confirm, death, longtime, soccer, sports...        Russell Lewis
# 11814  [RT, @, BukayoSaka87, :, childhood, dream, pla...    Dick fulchers lad
#
#                             Location                Date   Likes  Shares
# 11760                            NaN 2022-11-12 13:00:01  629808  236759
# 10585                          Qatar 2022-11-20 23:28:34  127116   53379
# 21390                 Milano, Italia 2022-12-11 01:02:03  231247   27972
# 11710          team@thesocialsup.com 2022-11-12 16:33:00  149618   27087
# 10593            London, Newick, LA. 2022-11-21 01:20:41  133871   21023
# 10412             QUEENSCLIFF Sydney 2022-11-21 05:26:15       0   21023
# 10318      Brancaster , Norfolk , UK 2022-11-21 03:02:35       0   20332
# 10934      Brancaster , Norfolk , UK 2022-11-20 00:53:47       0   20147
# 10933                            NaN 2022-11-19 19:17:28  119784   20147
# 10845                 Abuja, Nigeria 2022-11-20 04:32:20       0   19205
# 25127                 Milano, Italia 2022-12-19 03:50:35  184694   16489
# 25996                          QATAR 2022-12-19 03:05:25   77246   12013
# 8301           team@thesocialsup.com 2022-11-21 19:49:54   37336   11249
# 24209                            NaN 2022-12-10 05:10:05   63098   10947
# 21639  Jammu, Jammu & Kashmir, India 2022-12-10 20:04:03       0   10947
# 25091    United Kingdom or somewhere 2022-12-19 01:07:52   43703   10628
# 21641                  Washington DC 2022-12-11 00:59:04       0   10079
# 22273                 Milano, Italia 2022-12-11 00:57:24   79118   10072
# 23496                    Doha, Qatar 2022-12-10 10:13:44   42981    9762
# 11814               Bedford, England 2022-11-10 23:09:38       0    9465

# %%
#Drop times
